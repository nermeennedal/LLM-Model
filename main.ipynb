# %%
import os 
from openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-480016f3bfbd> in <module>
#       1 import os
# ----> 2 from openai import OpenAI
#
# ModuleNotFoundError: No module named 'openai'

# %%
key=os.getenv("OPENAAI_API_KEY")
model=os.getenv("DEAFULT_MODEL")
print(key)
model
# Out:
# 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
# 'gpt-5-mini'

# %%
massage="Hi , chat iam nermeen ! "
massages=[{"role":"user"},{"content":massage}]
massages
# Out:
# [{'role': 'user'}, {'content': 'Hi , chat iam nermeen ! '}]

# %%
massages2=[
{"role":"user","content":massage},
{"role":"assisstent","content":"hi how are you"},
{"role":"user","content":"how are you too"}
]

# %%
openai=OpenAI()
response=openai.chat.completions.create(model=model,messages=massages)
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b902a900f9f4> in <module>
# ----> 1 openai=OpenAI()
#       2 response=openai.chat.completions.create(model=model,messages=massages)
#       3 response
#
# NameError: name 'OpenAI' is not defined
